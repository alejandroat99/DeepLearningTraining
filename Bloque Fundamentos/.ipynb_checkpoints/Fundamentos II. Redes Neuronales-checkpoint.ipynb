# %% [markdown]
# ## Fundamentos II. Redes Neuronales
# En este cuadernos se verán todos los fundamentos de las redes neuronales donde veremos temas como la neurona básica, las funciones de activación y el algoritmo de Backpropagation.
#
# ## 1. La Neurona
# Comenzaremos estudiando la unidad básica de todas las redes neronales, la **Neurona**. Una neurona es la unidad básica de procesamiento de datos en una red neuronal. El procesamiento que se realiza en una neurona es en realidad bastante simple, consiste en tomar los datos de entrada y combinarlos mediante una suma ponderada. Una vez que tenemos el resultado de la suma vemos si el resultado supera un umbral y dependiendo del umbral se envía un resultado u otro a las siguiente neuronas.
#
# Dada una neurona con los pesos de sus entradas `w` y un conjunto de entradas `x`, la suma ponderada realizada en una neurona se define como:
#
# <center>$ \sum_{i=1}^{N} w_i \cdot x_i $</center>

# %%
import numpy as np
# Este es un ejemplo de como se ralizaria la suma ponderada de una neurona normal
x = np.asarray([3, 6, 9, 34, 12])
w = np.asarray([2, 0.5, 1, 5, 0.75])
resultado = np.sum(w*x)
print('Suma Ponderada: ', resultado)
# Out:
# Suma Ponderada:  197.0

# %% [markdown]
# Dado que el umbral puede variar de una neurona a otra y a lo largo de una red se tendrían que hacer muchas compararaciones distintas, se introduce el concepto de `Bias`. La bias es el negativo del umbral seleccionado y lo usamos sumándolo al resultado de la suma ponderada para conseguir que todos los umbrales se centren en cero.
#
# Siendo `t` el umbral definido para una neurona, el bias `b` se puede definir como $ b \equiv -t $. Siguiendo con lo mencionado anteriormente, el resultado del procesamiento de una neurona sería:
#
# <center>$z = \left\{ \begin{array}{lcc}
# 1 &   si  & w \cdot x + b > 0\\
# \\ 0 &  \text{otro caso} \\
# \end{array}
# \right.$</center>

# %%
# Usando el codigo anterior, definir un bias y devolver el resultado de la neurona
b = -4
resultado = resultado + b
if resultado > 0:
    z = 1
else:
    z = 0
    
print('Output (z):', z)
# Out:
# Output (z): 1

# %% [markdown]
# Este enfoque sólo permite obtener resultados binarios del procesamiento, esto no es muy útil a la hora del aprendizaje debido a que provoca resultados muy extremos que no se llegarían a ajustar a la realidad del modelo que querermos desarrollar.
#
# ## 2. Funciones de Activación
# Para solucionar este problema se introduce un paso más en el procesamiento y serían la funciones de activación. Estas funciones tratan de evitar la salida binaria de la neurona usando el resultado de la suma ponderada $z = w \cdot x + b$ con el objetivo de suavizar el resultado. A continuación veremos algunas de las funciones más utilizadas.
#
# ## 2.1 Sigmoide
# La función **Sigmoide** proporciona una curva más suaves de resultados, siendo esta definida como:
# <center>$\sigma(z) = \frac{1}{1+e^{-z}}$</center>

# %%
import matplotlib.pyplot as plt
x = np.linspace(-10,10)
f = 1 / (1 + np.exp(x))
plt.plot(x,f)
plt.grid()
plt.show()

# %% [markdown]
# Esta función tiene un problema y es que cuando se realizan cambios sutiles en los pesos y en las bias durante el entrenamiento, las actualizaciones tendrán poco o ningún efecto en el rendimiento, y por lo tanto el aprendizaje se estancará. Esta situación se conoce como "Neuron Saturation" y ocurre con las mayorías de las funciones de activación.
#
# ### 2.2 Función de Tahn
# La función de Tahn permite centrar la activación de le neurona en cero, de forma que las salidas `z` negativas tendrán una activación negativa y las `z` positivas tendrán una activación positiva. Este tipo de funciones se utilizan para generar entradas para otras neurones, hacen menos probable la "Neuron Saturation" y permiten que la red aprenda de una forma más eficiente.
#
# <center>$\sigma(z) = \frac{e^z - e^{-z}}{e^z + e^{-z}}$</center>

# %%
f = (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))
plt.plot(x,f)
plt.grid()
plt.show()

# %% [markdown]
# ### 2.3 Función ReLU
# La función ReLU (rectified Linear Unit) es una función no lineal que utiliza el operador máximo. Al utilizar una función de activación no lineal es posible aproximar cualquier función continua. Este tipo de funciones de activación son de las más usadas.
#
# <center>$\sigma(z) = \max(0,z)$</center>

# %%
f = [ np.max([0,a]) for a in x]
plt.plot(x,f)
plt.grid()
plt.show()

# %% [markdown]
# Ejercicio. Implementar una neurona funcional con las siguientes funciones de activación:
# - Función Sigmoide
# - Función de Tahn
# - Función ReLU

# %%
class Neurona():
    def __init__(self, pesos, bias, activacion):
        """
        Esta clase representa el funcionamiento de una neurona básica. Los parametros del constructor son:
        - Pesos: lista numpy de los pesos de las entradas
        - Bias: bias de la neurona
        - Activacion: funcion lambda de activacion
        """
        self.pesos = pesos
        self.bias = bias
        self.f = activacion
    
    def predict(self, entradas):
        """Función que realiza el procesamiento de la neurona"""
        assert len(entradas) == len(self.pesos)
        z = np.sum(self.pesos * entradas) + self.bias
        return self.f(z)
    
    def __str__(self):
        return f'Neurona({len(self.pesos)}, {self.bias})'

# %%
sigmoid = lambda z: 1 / (1 + np.exp(z))
tahn = lambda z: (np.exp(z) - np.exp(-z)) / (np.exp(z) + np.exp(-z))
relu = lambda z: np.max([0,z])

w = np.asarray([0.5, 1.5, 10, 4])
b = 50
sigmoid_neuron = Neurona(pesos=w, bias=b, activacion=sigmoid)
tahn_neuron = Neurona(pesos=w, bias=b, activacion=tahn)
relu_neuron = Neurona(pesos=w, bias=b, activacion=relu)

# %%
data = np.asarray([1,2,3,4])
sigmoid_output = sigmoid_neuron.predict(data)
tahn_output = tahn_neuron.predict(data)
relu_output = relu_neuron.predict(data)
print(f'Resultados:\n\t-Sigmoid: {sigmoid_output}\n\t-Tahn: {tahn_output}\n\t-ReLU: {relu_output}')
# Out:
# Resultados:
# 	-Sigmoid: 6.133368390286091e-44
# 	-Tahn: 1.0
# 	-ReLU: 99.5

# %% [markdown]
# ## 3. La importancia de las derivadas
# Ahora que ya hemos visto como funciona el procesamiento de los datos dentro de una neurona, podemos avanzar para ver cómo aprende la neurona. Como se mencionó en secciones anteriores, la neurona aprende ajustando sus parámetros: los pesos y la bias. Pero una red neuronal no está formada por una sola neurona, incluso las redes neuronales más sencillas pueden tener cientos de parámetros y cada uno de ellos afecta a los demás. Esto nos lleva a preguntarno cómo ajustamos los parámetros si aparentemento es una tarea imposible.
#
# La respuesta es tratar el ajuste de los parámetros como si fuese un problema de optimización, el objetivo de este problema puede resumirse como: ¿Cuál es el conjunto de parámetros que consigue minimizar la función la función de coste de la red? Si tratamos la red como si fuese una función matemática y la mapeamos frente a los resultados que proporciona en la función de coste, podemos ver las zonas donde se encuentran los mínimos relativos y absolutos de la función.
#
# Todo problema de optimización de funciones, tiene como base la derivada que permite conocer la tendencia de la función en un punto, es decir, nos permite saber si la función esta creciendo o decreciendo. Con esto podemos encontrar los mínimos de la función debido a que podemos considerar como mínimo a un punto en el que el punto anterio esté decreciendo, el punto posterior esté creciendo y la derivada del punto sea cero.
#
# Aunque para las redes neuronales usamos el gradiente, que es la generalización de la derivada para cualquier dimensión.
#
# ### 3.1 Descenso del Gradiente
# El descenso del gradiente es una proposición matemática que indica que dada una función diferenciable, es, teóricamente, posible encontrar su mínimo de una forma analítica. Esto aplicado a las redes neuronales, significa que podemos encontrar una combinación de parámetros que permita obtener la mínima pérdida en la función de coste.
#
# Esto nos lleva a tratar de resolver la ecuación polinómica de $N$ variables, siendo $N$ el número de parámetros de la red. Pero resolver una ecuación de tal tamaño es computacionalmente inasumible en tiempo de ejecución. Por ello los que en realidad se hace es un proceso de aproximación. El proceso de aproximación se basa en coger el punto actual donde se ecuentra la red y calcular su gradiente. El gradiente es utilizado para saber en qué dirección del especia debemos modificar los parámetros. Este proceso se repite todas las veces que sean necesarias hasta alcanzar un punto que consideremos el mínimo.
#
# Debemos tener en cuenta que las modificaciones no pueden ser demasiado pequeñas porque tardaríamos demasiado ni demasiado grandes ya que no tendríamos la exactitud necesaria. Este paso con el que se modifican los parámetros se conoce como **Learning Rate**.
#
# Esta es la técnica base utilizada para solucionar el problema de minimización pero presenta un problema importante y es que le proceso termina cuando ha encontrado un mínimo pero este puede no ser un mínimo absoluto. Es decir, puede que haya encontrado una buena combinación de parámetros pero puede no ser la mejor de todas.
#
# Para solucionar este problema es posible realizar una pequeña modificación al algoritmo para que tenga en cuenta el momento y la velociadad del gradiente de la función, este enfoque viene inspirado de la _Física_. Con este enfoque los parámetros de la red son modificados según el valor del gradiente y por las modificaciones anteriores.
#
# ### 3.2 Algoritmo de Backpropagation
# El **Algoritmo de Backpropagation** es el algoritmo por execelencia que implementa el **Descenso del Gradiente** en las redes neuronales. Esto se debe a que no podemos computar de manera explícita el gradiente de una red neuronal a causa de que una red neuronale es el encadenamiento de operaciones sobre vectores o mejor conocidos como _tensores_ y cada una de estas operaciones tiene un gradiente conocido y sencillo.
#
# Con este problema, el algoritmo de Backpropagation hace uso de la **Regla de la Cadena**:
#
# <center>$\begin{eqnarray*}
# (g \circ f)(x) = g(f(x)) \\
# (g \circ f)'(x) = g'(f(x)) \cdot f'(x)
# \end{eqnarray*}$</center>
#
# Debido a esta regla saca su nombre el algoritmo, ya que se empieza desde el final de la red, es decir, desde la neurona de salida hasta las capas iniciales de red, aplicando la regla de la cadena para conocer la influencia que tiene cada parámetro al coste total de la red. Actualmente existen librerías como _TensorFlow_ capaces de realizar **Diferenciación Simbólica** de manera automática, ahorrando tener que calcular el gradiente de cada red de forma manual.

# %%
# Ejercicio en el que hay que realizar una red neuronal sencilla y
# programar el aprendizaje de la red manualmente haciendo uso del algoritmo
# de backprogation y de la regla de la cadena.
# ...

# %% [markdown]
# ## 4. Funciones de Coste
# Existen muchas **Funciones de Coste** diferentes, cada una de ellas con características especiales que las adecuan más que otras para resolver cierto tipo de problemas. Las funciones que han demostrado los mejores resultados en cada tipo de problema de redes neuronales son:
# - **Binary Cross-entropy**: problemas de clasificación binaria
# - **Categorical Cross-entropy**: problemas de clasificación con varias clases
# - **Error Cuadratico Medio**: problemas de regresión
# - **Connectionist Temporal Classification (CTC)**: problemas de aprrendizaje de secuencias.
